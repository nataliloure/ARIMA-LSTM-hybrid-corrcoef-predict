# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliloure/ARIMA-LSTM-hybrid-corrcoef-predict/blob/master/MeuDesafioETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Desafio Explorando IA Generativa em um Pipeline de ETL com Python do Santander Bootcamp 2023 - Ciência de Dados com Python

# %%
import pandas as pd

df_books = pd.read_csv('goodreads_library_export.csv', delimiter = ',')
df_books.head(10)
# Out:
#     Book Id                                      Title            Author  \
# 0     25179                                   Blankets    Craig Thompson
# 1    156534          Y: The Last Man, Vol. 1: Unmanned  Brian K. Vaughan
# 2  15704307                             Saga, Volume 1  Brian K. Vaughan
# 3     96358                   Batman: The Killing Joke        Alan Moore
# 4     59960            Batman: The Dark Knight Returns      Frank Miller
# 5     23754  The Sandman, Vol. 1: Preludes & Nocturnes       Neil Gaiman
# 6    991197                    The Complete Persepolis   Marjane Satrapi
# 7      5805                             V for Vendetta        Alan Moore
# 8     15195                          The Complete Maus    Art Spiegelman
# 9    472331                                   Watchmen        Alan Moore
#
#           Author l-f        ISBN         ISBN13  Average Rating  \
# 0    Thompson, Craig  1891830430  9781891830433            4.05
# ...

# %%
df_books['Minhas Notas'] = ['5', '3', '4', '5', '5', '5', '3', '4', '5', '5']
df_books.head(10)
# Out:
#     Book Id                                      Title            Author  \
# 0     25179                                   Blankets    Craig Thompson
# 1    156534          Y: The Last Man, Vol. 1: Unmanned  Brian K. Vaughan
# 2  15704307                             Saga, Volume 1  Brian K. Vaughan
# 3     96358                   Batman: The Killing Joke        Alan Moore
# 4     59960            Batman: The Dark Knight Returns      Frank Miller
# 5     23754  The Sandman, Vol. 1: Preludes & Nocturnes       Neil Gaiman
# 6    991197                    The Complete Persepolis   Marjane Satrapi
# 7      5805                             V for Vendetta        Alan Moore
# 8     15195                          The Complete Maus    Art Spiegelman
# 9    472331                                   Watchmen        Alan Moore
#
#           Author l-f        ISBN         ISBN13  Average Rating  \
# 0    Thompson, Craig  1891830430  9781891830433            4.05
# ...

# %%
df_books.to_csv('./atualizado.csv',sep = ';', index = False)
